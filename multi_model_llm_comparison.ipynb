# %% [markdown]
# # Multi-Model Benchmarking of Lightweight Open-Source Generative AI Models
#
# ## Objective
# This notebook evaluates and compares multiple lightweight publicly available generative ai models under identical conditions
#
#
# The goal is to understand trade-offs in:
# 1. Instruction following
# 2. Conversational quality
# 3. Response verbosity
# 4. Inference latency
#
# This type of comparison mirrors real-world model selection in GenAI systems.

# %% [markdown]
# ## Models Evaluated
#
# | Model Name | Architecture | Tuning Type | Reason for Inclusion |
# |-----------|-------------|-------------|---------------------|
# | BlenderBot-400M | Encoder-Decoder | Dialogue-tuned | Conversational baseline |
# | FLAN-T5-Small | Encoder-Decoder | Instruction-tuned | Lightweight instruction model |
# | FLAN-T5-Base | Encoder-Decoder | Instruction-tuned | Scale comparison |

# %% [markdown]
# ## Experimental Setup
#
# 1. Same prompts for all models
# 2. Greedy decoding (no sampling)
# 3. Max output length: 128 tokens
# 4. CPU inference
# 5. No fine-tuning applied
#
# This ensures a fair, controlled comparison.

# %% [markdown]
# ### The following packages are required to be installed to run the models

# %%
# %pip install transformers tensorflow sentencepiece numpy pandas
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (4.42.1)
# Requirement already satisfied: tensorflow in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: sentencepiece in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (0.2.1)
# Requirement already satisfied: numpy in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (1.26.0)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: filelock in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (3.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: setuptools in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (44.1.1)
# Requirement already satisfied: six>=1.12.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (1.2.0)
# Requirement already satisfied: rich in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/user/Documents/dev programmer/learning/school project/LLM/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 15.0 MB/s eta 0:00:00 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-2.3.3 pytz-2025.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    BlenderbotTokenizer,
    BlenderbotForConditionalGeneration
)
import pandas as pd

# %%
MODELS = {
    "blenderbot": "facebook/blenderbot-400M-distill",
    "flan_t5_small": "google/flan-t5-small",
    "flan_t5_base": "google/flan-t5-base",
}

MAX_TOKENS = 128

# %% [markdown]
# ## Evaluation Prompts
#
# The following prompts are used for all models.
# They test instruction following, reasoning, and conversational ability.

# %%
PROMPTS = [
    "Explain overfitting in simple terms.",
    "Write a polite email declining a meeting.",
    "What are the pros and cons of electric cars?",
]

# %%
def load_model(model_name: str):

    if "blenderbot" in model_name.lower():
        tokenizer = BlenderbotTokenizer.from_pretrained(model_name)
        model = BlenderbotForConditionalGeneration.from_pretrained(model_name)
    else:
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

    model.eval()
    return model, tokenizer

# %%
def generate_response(model, tokenizer, prompt):
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True)
    outputs = model.generate(
        **inputs,
        max_length=MAX_TOKENS
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
results = []

for model_key, model_name in MODELS.items():
    model, tokenizer = load_model(model_name)
    for prompt in PROMPTS:
        output = generate_response(model, tokenizer, prompt)
        results.append({
            "model": model_key,
            "prompt": prompt,
            "output": output
        })
# Out:
# '(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), '(Request ID: 1be58f21-6654-4f33-85eb-a394d5fbc08d)')' thrown while requesting HEAD https://huggingface.co/facebook/blenderbot-400M-distill/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].

# %%
df = pd.DataFrame(results)
df
# Out:
#            model                                        prompt  \
# 0     blenderbot          Explain overfitting in simple terms.
# 1     blenderbot     Write a polite email declining a meeting.
# 2     blenderbot  What are the pros and cons of electric cars?
# 3  flan_t5_small          Explain overfitting in simple terms.
# 4  flan_t5_small     Write a polite email declining a meeting.
# 5  flan_t5_small  What are the pros and cons of electric cars?
# 6   flan_t5_base          Explain overfitting in simple terms.
# 7   flan_t5_base     Write a polite email declining a meeting.
# 8   flan_t5_base  What are the pros and cons of electric cars?
#
#                                               output
# 0   I'm trying to get rid of some of my excess we...
# 1   I hate when that happens.  What did you end u...
# 2   Electric cars are so much better than gasolin...
# 3  The overfitting is a way to get the most out o...
# 4  I'm not sure if I'll be able to attend the mee...
# 5      Electric cars are powered by a single engine.
# 6  Overfitting is the state of being too small or...
# 7  I'm sorry to hear that you are unable to atten...
# 8  Electric cars are more efficient than fossil f...

# %% [markdown]
# ## RESULT ANALYSIS
#
# ### Blenderbot-400
# 1. It produces fluent, conversational responses
# 2. It frequently ignores instructions and treats the dialogue as continuation
# 3. It performs poorly on task oriented queries
#
# **Conclusion:** It well-suited for open-domain chat, but not for instruction-following tasks.
#
# ---
#
# ### FLAN-T5-Base
# - It attempts to follow instructions but often produces incorrect or repetitive outputs.
# - It shows limited reasoning depth and instability in longer generations.
#
# **Conclusion:** It is aware of instructions but unreliable without decoding or prompt tuning.
#
# ---
#
# ### FLAN-T5-Small
# - It generates shallow, repetitive, or nonsensical responses.
# - It fails to explain basic concepts accurately.
#
# **Conclusion:** The model's capacity is insufficient for reliable generative reasoning.
